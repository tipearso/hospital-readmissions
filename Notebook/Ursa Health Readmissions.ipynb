# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
greatcare_members = pd.read_csv('../data/NSS_GreatCare_Members.csv')
greatcare_members.head()
# Out:
#   Patient ID Primary Plan ID Primary Payor ID  Is Patient Alive  \
# 0      DS1|1       DS1|5047W            DS1|1                 1
# 1     DS1|10       DS1|5047W            DS1|1                 1
# 2    DS1|100       DS1|5047W            DS1|1                 1
# 3   DS1|1000       DS1|5047W            DS1|1                 1
# 4  DS1|10000       DS1|5047W            DS1|1                 1
#
#    Patient Age Integer Patient Date of Birth  Patient ZIP Code 5-Digit  \
# 0                   54            1958-11-08                   92111.0
# 1                   54            1958-12-10                   90024.0
# 2                    2            2012-08-04                   90008.0
# 3                    6            2003-12-25                   94131.0
# 4                    7            2005-07-15                   90301.0
#
#    Count Primary Care Visits in Last 36 Months  \
# 0                                            0
# 1                                            6
# ...

# %%
hospital_inpatient_admissions = pd.read_csv('../data/NSS_Hospital_Inpatient_Admissions.csv')
hospital_inpatient_admissions.head(10)
hospital_inpatient_admissions.sort_values(by=['Patient ID'])
# Out:
#                             Encounter ID Patient ID  \
# 117      HIA|DS1|10|DS1|NPI|1710918545|1     DS1|10
# 0     HIA|DS1|10033|DS1|NPI|1306890389|1  DS1|10033
# 1     HIA|DS1|10043|DS1|NPI|1902803315|1  DS1|10043
# 2     HIA|DS1|10073|DS1|NPI|1902803315|1  DS1|10073
# 3     HIA|DS1|10101|DS1|NPI|1427055839|1  DS1|10101
# ...                                  ...        ...
# 6208   HIA|DS1|9979|DS1|NPI|1689772592|1   DS1|9979
# 6209   HIA|DS1|9981|DS1|NPI|1427055839|1   DS1|9981
# 6211   HIA|DS1|9994|DS1|NPI|1689608150|2   DS1|9994
# 6210   HIA|DS1|9994|DS1|NPI|1689608150|1   DS1|9994
# 6212   HIA|DS1|9996|DS1|NPI|1033298617|1   DS1|9996
#
#      Encounter Primary Payor ID Encounter Primary Plan ID  \
# 117                       DS1|1                 DS1|5047W
# 0                         DS1|1                 DS1|5047W
# 1                         DS1|1                 DS1|5047Y
# 2                         DS1|1                 DS1|5047X
# ...

# %%
primarycare_office_visits = pd.read_csv('../data/NSS_PrimaryCare_Office_Visits.csv', low_memory=False)
primarycare_office_visits.head()
primarycare_office_visits = .sort_values(by=['
# Out:
#   File "<ipython-input-4-735dff4fd62a>", line 3
#     primarycare_office_visits = .sort_values(by=['
#                                 ^
# SyntaxError: invalid syntax

# %%
# admissions[['First','second','third','fourth','fifth','sixth','Last']] = admissions['Encounter ID'].apply(
#    lambda x: pd.Series(str(x).split("|")))
# admissions.head()
